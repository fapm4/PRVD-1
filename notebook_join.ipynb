# %% [markdown]
# ## Objetivo
#
# Unir los datasets de YRBS y el de Kaggle en las variables comunes.

# %% [markdown]
# ### YRBS 2021

# %%
import pyodbc
import pandas as pd

# Ruta al archivo .mdb
mdb_file = "datos/XXH2021_YRBS_Data.mdb"

# Crear la conexión con pyodbc
conn = pyodbc.connect(
    r"Driver={Microsoft Access Driver (*.mdb, *.accdb)};"
    f"DBQ={mdb_file};"
)

# Consulta SQL para leer datos de una tabla específica
query_q = "SELECT * FROM XXHq"  # set de preguntas Q


# Ejecutar la consulta y cargar los datos en un DataFrame
df = pd.read_sql(query_q, conn)


# Cerrar la conexión
conn.close()

# Mostrar las primeras filas del DataFrame
df.head()
# Out:
# C:\Users\Multivac Desktop\AppData\Local\Temp\ipykernel_21184\1643613083.py:18: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query_q, conn)
#   site raceeth q6orig q7orig  record orig_rec q1 q2    q3 q4  ... q94  q95  \
# 0   XX       3    502    155     1.0     None  5  1     3  2  ...   2    1
# 1   XX       7    509   None     2.0     None  4  2  None  1  ...   3    3
# 2   XX       6    507    136     3.0     None  4  2     2  1  ...   2    3
# 3   XX       6    509    133     4.0     None  4  2     2  1  ...   2    3
# 4   XX       7    603    196     5.0     None  3  2     2  1  ...   2    3
#
#    q96 q97 q98 q99     BMIPCT  weight stratum      psu
# 0    5   4   1   1  94.097808  3.6444   214.0  87023.0
# 1    1   5   1   1        NaN  4.1426   214.0  87023.0
# 2    2   4   1   1  65.303280  4.1426   214.0  87023.0
# 3    3   3   2   2  42.734624  4.1426   214.0  87023.0
# 4    2   5   1   1  91.260653  4.1426   214.0  87023.0
#
# [5 rows x 109 columns]

# %%
# Cogemos las variables que vamos a estudiar
df_y21 = df[['q1', 'q2', 'q3', 'q24', 'q25', 'q26', 'q28', 'q41', 'q78', 'q85', 'q86', 'q98']]
df_y21.columns = ['age', 'gender', 'school_grade', 'electronic_bullying', 'stop_daily_activities', 'consider_suicide', 'attempt_suicide', 'current_alcohol', 'social_use', 'depressed', 'sleep_issues', 'concentrate'  ]
df_y21['year'] = 2021
df_y21
# Out:
# C:\Users\Multivac Desktop\AppData\Local\Temp\ipykernel_21184\4066503544.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_y21['year'] = 2021
#       age gender school_grade electronic_bullying stop_daily_activities  \
# 0       5      1            3                   2                     1
# 1       4      2         None                   1                     1
# 2       4      2            2                   2                     1
# 3       4      2            2                   2                     2
# 4       3      2            2                   2                     1
# ...    ..    ...          ...                 ...                   ...
# 17227   5      1            2                   1                     2
# 17228   6      2            4                   2                     1
# 17229   4      2            1                   1                     1
# 17230   4      1            1                   1                     1
# 17231   7      1            4                   2                     2
#
#       consider_suicide attempt_suicide current_alcohol social_use depressed  \
# 0                    1               2               3          6         5
# 1                    2               1               1          6         4
# 2                    1               2               1          6         4
# 3                    2               1            None          4         2
# 4                    2               1               2          6         3
# ...                ...             ...             ...        ...       ...
# 17227                2               1               4          3      None
# 17228                2               1               1          5      None
# 17229                2               2               2       None      None
# 17230                1               3               5          6      None
# 17231                2               1               1          4      None
#
#       sleep_issues concentrate  year
# 0                2           1  2021
# 1                5           1  2021
# 2                5           1  2021
# 3                4           2  2021
# 4                4           1  2021
# ...            ...         ...   ...
# 17227            5        None  2021
# 17228            3        None  2021
# 17229         None        None  2021
# 17230         None        None  2021
# 17231            5        None  2021
#
# [17232 rows x 13 columns]

# %% [markdown]
# ### YRBS 2023

# %%
import pyodbc
import pandas as pd

# Ruta al archivo .mdb
mdb_file = "datos/XXH2023_YRBS_Data.mdb"

# Crear la conexión con pyodbc
conn = pyodbc.connect(
    r"Driver={Microsoft Access Driver (*.mdb, *.accdb)};"
    f"DBQ={mdb_file};"
)

# Consulta SQL para leer datos de una tabla específica
query_q = "SELECT * FROM XXHq"  # set de preguntas Q


# Ejecutar la consulta y cargar los datos en un DataFrame
df = pd.read_sql(query_q, conn)


# Cerrar la conexión
conn.close()

# Mostrar las primeras filas del DataFrame
df.head()
# Out:
# C:\Users\Multivac Desktop\AppData\Local\Temp\ipykernel_21184\2022595171.py:18: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query_q, conn)
#   site raceeth q6orig q7orig  record orig_rec q1 q2 q3    q4  ... q102  q103  \
# 0   XX    None    505    180     1.0     None  3  1  1  None  ...    2     3
# 1   XX       5    N N    233     2.0     None  4  2  1     2  ...    2     2
# 2   XX       5    506    165     3.0     None  5  2  3     2  ...    1     2
# 3   XX       5    N N    105     4.0     None  6  1  2     2  ...    2     4
# 4   XX       5    601    125     5.0     None  3  2  1     2  ...    2     2
#
#    q104 q105 q106 q107     BMIPCT  weight stratum      psu
# 0     3    2    2    2  97.083855  0.8614   103.0  16294.0
# 1     5    2    1    2        NaN  0.8920   103.0  16294.0
# 2     4    2    2    1  92.262516  0.5081   103.0  16294.0
# 3     5    2    1    1        NaN  1.1759   103.0  16294.0
# 4     5    2    2    1   7.567053  0.8920   103.0  16294.0
#
# [5 rows x 117 columns]

# %%
# Cogemos las variables que vamos a estudiar
df_y23 = df[['q1', 'q2', 'q3', 'q25', 'q26', 'q27', 'q29', 'q42', 'q80', 'q84', 'q85', 'q87']]
df_y23.columns = ['age', 'gender', 'school_grade', 'electronic_bullying', 'stop_daily_activities', 'consider_suicide', 'attempt_suicide', 'current_alcohol', 'social_use', 'depressed', 'sleep_issues', 'academic_grades']
df_y23['year'] = 2023
df_y23
# Out:
# C:\Users\Multivac Desktop\AppData\Local\Temp\ipykernel_21184\1152768965.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_y23['year'] = 2023
#       age gender school_grade electronic_bullying stop_daily_activities  \
# 0       3      1            1                   2                     1
# 1       4      2            1                   2                     2
# 2       5      2            3                   2                     1
# 3       6      1            2                   2                     1
# 4       3      2            1                   2                     1
# ...    ..    ...          ...                 ...                   ...
# 20098   3      1            1                   1                     1
# 20099   4      2            1                   2                     1
# 20100   4      2            1                   2                     2
# 20101   5      2            1                   2                     2
# 20102   4      1            1                   2                     2
#
#       consider_suicide attempt_suicide current_alcohol social_use depressed  \
# 0                    2               1               1          6         1
# 1                    2               1               1          4         3
# 2                    2               1               1          8         2
# 3                    2               1               2          8         3
# 4                    2               1               2          6         3
# ...                ...             ...             ...        ...       ...
# 20098                1               1               1          1      None
# 20099                2               1               1          8      None
# 20100                2               1               1          1      None
# 20101                2               1               1          8      None
# 20102                2            None               1          6      None
#
#       sleep_issues academic_grades  year
# 0                3            None  2023
# 1                5               4  2023
# 2                1               3  2023
# 3                4               3  2023
# 4                3               4  2023
# ...            ...             ...   ...
# 20098            3            None  2023
# 20099            6               3  2023
# 20100            5               1  2023
# 20101            3               4  2023
# 20102            1               3  2023
#
# [20103 rows x 13 columns]

# %%
# Rellenar nulos con 0 para convertir a entero
# df_y = df_y.fillna(0)
# df_y = df_y.astype('int32')

# %% [markdown]
# ### Kaggle

# %%
import pandas as pd

file_path = 'datos/smmh.csv'
df_k = pd.read_csv(file_path)

df_k['Timestamp'] = pd.to_datetime(df_k['Timestamp'])
df_k['year'] = df_k['Timestamp'].dt.year

df_k.head()
# Out:
#             Timestamp  1. What is your age? 2. Gender 3. Relationship Status  \
# 0 2022-04-18 19:18:47                  21.0      Male      In a relationship
# 1 2022-04-18 19:19:28                  21.0    Female                 Single
# 2 2022-04-18 19:25:59                  21.0    Female                 Single
# 3 2022-04-18 19:29:43                  21.0    Female                 Single
# 4 2022-04-18 19:33:31                  21.0    Female                 Single
#
#   4. Occupation Status 5. What type of organizations are you affiliated with?  \
# 0   University Student                                         University
# 1   University Student                                         University
# 2   University Student                                         University
# 3   University Student                                         University
# 4   University Student                                         University
#
#   6. Do you use social media?  \
# 0                         Yes
# 1                         Yes
# 2                         Yes
# 3                         Yes
# 4                         Yes
#
#   7. What social media platforms do you commonly use?  \
# 0  Facebook, Twitter, Instagram, YouTube, Discord...
# 1  Facebook, Twitter, Instagram, YouTube, Discord...
# 2            Facebook, Instagram, YouTube, Pinterest
# 3                                Facebook, Instagram
# 4                       Facebook, Instagram, YouTube
#
#   8. What is the average time you spend on social media every day?  \
# 0                              Between 2 and 3 hours
# 1                                  More than 5 hours
# 2                              Between 3 and 4 hours
# 3                                  More than 5 hours
# 4                              Between 2 and 3 hours
#
#    9. How often do you find yourself using Social media without a specific purpose?  \
# 0                                                  5
# 1                                                  4
# 2                                                  3
# 3                                                  4
# 4                                                  3
#
#    ...  12. On a scale of 1 to 5, how easily distracted are you?  \
# 0  ...                                                  5
# 1  ...                                                  4
# 2  ...                                                  2
# 3  ...                                                  3
# 4  ...                                                  4
#
#    13. On a scale of 1 to 5, how much are you bothered by worries?  \
# 0                                                  2
# 1                                                  5
# 2                                                  5
# 3                                                  5
# 4                                                  5
#
#    14. Do you find it difficult to concentrate on things?  \
# 0                                                  5
# 1                                                  4
# 2                                                  4
# 3                                                  3
# 4                                                  5
#
#    15. On a scale of 1-5, how often do you compare yourself to other successful people through the use of social media?  \
# 0                                                  2
# 1                                                  5
# 2                                                  3
# 3                                                  5
# 4                                                  3
#
#    16. Following the previous question, how do you feel about these comparisons, generally speaking?  \
# 0                                                  3
# 1                                                  1
# 2                                                  3
# 3                                                  1
# 4                                                  3
#
#    17. How often do you look to seek validation from features of social media?  \
# 0                                                  2
# 1                                                  1
# 2                                                  1
# 3                                                  2
# 4                                                  3
#
#    18. How often do you feel depressed or down?  \
# 0                                             5
# 1                                             5
# 2                                             4
# 3                                             4
# 4                                             4
#
#    19. On a scale of 1 to 5, how frequently does your interest in daily activities fluctuate?  \
# 0                                                  4
# 1                                                  4
# 2                                                  2
# 3                                                  3
# 4                                                  4
#
#    20. On a scale of 1 to 5, how often do you face issues regarding sleep?  \
# 0                                                  5
# 1                                                  5
# 2                                                  5
# 3                                                  2
# 4                                                  1
#
#    year
# 0  2022
# 1  2022
# 2  2022
# 3  2022
# 4  2022
#
# [5 rows x 22 columns]

# %%
# Filtrar columnas que nos interesan
df_k = df_k.iloc[ :, [1, 2, 3, 4, 7, 8, 12, 14, 18, 19, 20, 21] ]
df_k
# Out:
#      1. What is your age? 2. Gender 3. Relationship Status  \
# 0                    21.0      Male      In a relationship
# 1                    21.0    Female                 Single
# 2                    21.0    Female                 Single
# 3                    21.0    Female                 Single
# 4                    21.0    Female                 Single
# ..                    ...       ...                    ...
# 476                  24.0      Male                 Single
# 477                  26.0    Female                Married
# 478                  29.0    Female                Married
# 479                  21.0      Male                 Single
# 480                  53.0      Male                Married
#
#     4. Occupation Status 7. What social media platforms do you commonly use?  \
# 0     University Student  Facebook, Twitter, Instagram, YouTube, Discord...
# 1     University Student  Facebook, Twitter, Instagram, YouTube, Discord...
# 2     University Student            Facebook, Instagram, YouTube, Pinterest
# 3     University Student                                Facebook, Instagram
# 4     University Student                       Facebook, Instagram, YouTube
# ..                   ...                                                ...
# 476      Salaried Worker                       Facebook, Instagram, YouTube
# 477      Salaried Worker                                  Facebook, YouTube
# 478      Salaried Worker                                  Facebook, YouTube
# 479   University Student  Facebook, Twitter, Instagram, YouTube, Discord...
# 480      Salaried Worker                                  Facebook, YouTube
#
#     8. What is the average time you spend on social media every day?  \
# 0                                Between 2 and 3 hours
# 1                                    More than 5 hours
# 2                                Between 3 and 4 hours
# 3                                    More than 5 hours
# 4                                Between 2 and 3 hours
# ..                                                 ...
# 476                              Between 2 and 3 hours
# 477                              Between 1 and 2 hours
# 478                              Between 2 and 3 hours
# 479                              Between 2 and 3 hours
# 480                                  Less than an Hour
#
#      12. On a scale of 1 to 5, how easily distracted are you?  \
# 0                                                    5
# 1                                                    4
# 2                                                    2
# 3                                                    3
# 4                                                    4
# ..                                                 ...
# 476                                                  4
# 477                                                  3
# 478                                                  3
# 479                                                  3
# 480                                                  3
#
#      14. Do you find it difficult to concentrate on things?  \
# 0                                                    5
# 1                                                    4
# 2                                                    4
# 3                                                    3
# 4                                                    5
# ..                                                 ...
# 476                                                  4
# 477                                                  4
# 478                                                  3
# 479                                                  2
# 480                                                  1
#
#      18. How often do you feel depressed or down?  \
# 0                                               5
# 1                                               5
# 2                                               4
# 3                                               4
# 4                                               4
# ..                                            ...
# 476                                             3
# 477                                             4
# 478                                             2
# 479                                             4
# 480                                             2
#
#      19. On a scale of 1 to 5, how frequently does your interest in daily activities fluctuate?  \
# 0                                                    4
# 1                                                    4
# 2                                                    2
# 3                                                    3
# 4                                                    4
# ..                                                 ...
# 476                                                  4
# 477                                                  4
# 478                                                  2
# 479                                                  5
# 480                                                  2
#
#      20. On a scale of 1 to 5, how often do you face issues regarding sleep?  \
# 0                                                    5
# 1                                                    5
# 2                                                    5
# 3                                                    2
# 4                                                    1
# ..                                                 ...
# 476                                                  4
# 477                                                  1
# 478                                                  2
# 479                                                  4
# 480                                                  3
#
#      year
# 0    2022
# 1    2022
# 2    2022
# 3    2022
# 4    2022
# ..    ...
# 476  2022
# 477  2022
# 478  2022
# 479  2022
# 480  2022
#
# [481 rows x 12 columns]

# %%
df_k.columns = ['age', 'gender', 'relationship', 'occupation', 'social_platforms', 'social_use', 'distracted', 'concentration', 'depressed', 'stop_daily_activities', 'sleep_issues', 'year']
df_k.columns
# Out:
# Index(['age', 'gender', 'relationship', 'occupation', 'social_platforms',
#        'social_use', 'distracted', 'concentration', 'depressed',
#        'stop_daily_activities', 'sleep_issues', 'year'],
#       dtype='object')

# %%
df_k['age'].notna().count()
# Out:
# 481

# %% [markdown]
# ## Unión

# %%
df_k.dtypes
# Out:
# age                                 float64
# gender                               object
# relationship                         object
# occupation                           object
# social_platforms                     object
# social_use                           object
# distracted                            int64
# concentration                         int64
# depressed                             int64
# stop_daily_activities                 int64
# sleep_issues                          int64
# year                                  int32
# age_normalized                        int32
# stop_daily_activities_normalized     object
# depressed_normalized                 object
# sleep_issues_normalized              object
# dtype: object

# %%
# Diccionarios de mapeo para cada variable

# Edad
map_age = {
    '1': 12,  
    '2': 13,
    '3': 14,
    '4': 15,
    '5': 16,
    '6': 17,
    '7': 18
}
df_y21['age_normalized'] = df_y21['age'].map(map_age)
df_y23['age_normalized'] = df_y23['age'].map(map_age)
df_k['age_normalized'] = df_k['age'].astype('int32')

# Género
map_gender = {'1': 'Female', '2': 'Male'}
df_y21['gender_normalized'] = df_y21['gender'].map(map_gender)
df_y23['gender_normalized'] = df_y23['gender'].map(map_gender)


# School grade y occupation
schoolGrade_to_occupation = {
    '1': 'School Student', #'9th grade',  
    '2': 'School Student', #'10th grade',
    '3': 'School Student', #'11th grade',
    '4': 'School Student', #'12th grade',
    '5': 'Salaried Worker' #'Ungraded or other grade'
}
df_y21['occupation_normalized']  = df_y21['school_grade'].map(schoolGrade_to_occupation)
df_y23['occupation_normalized']  = df_y23['school_grade'].map(schoolGrade_to_occupation)


# Stopped doing daily activities
map_dailyActivities = {'1': 'Yes', '2': 'No'}
df_y21['stop_daily_activities_normalized']  = df_y21['stop_daily_activities'].map(map_dailyActivities)
df_y23['stop_daily_activities_normalized']  = df_y23['stop_daily_activities'].map(map_dailyActivities)

scale_to_dailyActivities = { 1: 'No', 2: 'No', 3: 'Yes', 4: 'Yes', 5: 'Yes'}
df_k['stop_daily_activities_normalized'] = df_k['stop_daily_activities'].map(scale_to_dailyActivities)


# Social media use
frequency_to_hours_social = {
    '1': '0 hours', #'I do not use social media',
    '2': 'Less than an Hour', #'A few times a month',
    '3': 'Less than an Hour', #'About once a week',
    '4': 'Less than an Hour', #'A few times a week',
    '5': 'Between 1 and 2 hours', #'About once a day',
    '6': 'Between 2 and 3 hours', #'Several times a day',
    '7': 'Between 3 and 4 hours', #'About once an hour',
    '8': 'More than 5 hours' #'More than once an hour'
}
df_y23['social_use_normalized'] = df_y23['social_use'].map(frequency_to_hours_social)

map_social_use = {
    '1': 'Less than an Hour',
    '2': 'Between 1 and 2 hours',
    '3': 'Between 2 and 3 hours',
    '4': 'Between 3 and 4 hours',
    '5': 'Between 3 and 4 hours',
    '6': 'More than 5 hours'
}
df_y21['social_use_normalized'] = df_y21['social_use'].map(map_social_use)


# Depressed
map_depressed = {'1': 'Never', '2': 'Rarely', '3': 'Sometimes', '4': 'Most of the time', '5': 'Always'}
map_depressed_int = {1: 'Never', 2: 'Rarely', 3: 'Sometimes', 4: 'Most of the time', 5: 'Always'}
df_y21['depressed_normalized'] = df_y21['depressed'].map(map_depressed)
df_y23['depressed_normalized'] = df_y23['depressed'].map(map_depressed)
df_k['depressed_normalized'] = df_k['depressed'].map(map_depressed_int)


# Sleep issues
map_sleep = {
    '1': 'Yes', #'<=4h',
    '2': 'Yes', #'5h',
    '3': 'No', #'6h',
    '4': 'No', #'7h',
    '5': 'No', #'8h',
    '6': 'No', #'9h',
    '7': 'Yes' #'>=10h'
}
df_y21['sleep_issues_normalized'] = df_y21['sleep_issues'].map(map_sleep)
df_y23['sleep_issues_normalized'] = df_y23['sleep_issues'].map(map_sleep)

scale_sleep_to_bool = {
    1: 'No',
    2: 'No',
    3: 'No',
    4: 'Yes',
    5: 'Yes'
}
df_k['sleep_issues_normalized'] = df_k['sleep_issues'].map(scale_sleep_to_bool)
# Out:
# C:\Users\Multivac Desktop\AppData\Local\Temp\ipykernel_21184\2823067732.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_y23['age_normalized'] = df_y23['age'].map(map_age)
# C:\Users\Multivac Desktop\AppData\Local\Temp\ipykernel_21184\2823067732.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_y23['gender_normalized'] = df_y23['gender'].map(map_gender)
# C:\Users\Multivac Desktop\AppData\Local\Temp\ipykernel_21184\2823067732.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_y23['occupation_normalized']  = df_y23['school_grade'].map(schoolGrade_to_occupation)
# C:\Users\Multivac Desktop\AppData\Local\Temp\ipykernel_21184\2823067732.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_y23['stop_daily_activities_normalized']  = df_y23['stop_daily_activities'].map(map_dailyActivities)
# C:\Users\Multivac Desktop\AppData\Local\Temp\ipykernel_21184\2823067732.py:55: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_y23['social_use_normalized'] = df_y23['social_use'].map(frequency_to_hours_social)
# C:\Users\Multivac Desktop\AppData\Local\Temp\ipykernel_21184\2823067732.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_y23['depressed_normalized'] = df_y23['depressed'].map(map_depressed)
# C:\Users\Multivac Desktop\AppData\Local\Temp\ipykernel_21184\2823067732.py:87: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_y23['sleep_issues_normalized'] = df_y23['sleep_issues'].map(map_sleep)

# %%
# Seleccionamos aquellas variables que se pueden unir

df_k_normalized = df_k[['year', 'age_normalized', 'gender', 'occupation', 'stop_daily_activities_normalized', 'social_use', 'depressed_normalized', 'sleep_issues_normalized']]
df_k_normalized.columns = ['year', 'age', 'gender', 'occupation', 'stop_daily_activities', 'social_use', 'depressed', 'sleep_issues']

df_y21_normalized = df_y21[['year', 'age_normalized', 'gender_normalized', 'occupation_normalized', 'stop_daily_activities_normalized', 'social_use_normalized', 'depressed_normalized', 'sleep_issues_normalized']]
df_y21_normalized.columns = ['year', 'age', 'gender', 'occupation', 'stop_daily_activities', 'social_use', 'depressed', 'sleep_issues']

df_y23_normalized = df_y23[['year', 'age_normalized', 'gender_normalized', 'occupation_normalized', 'stop_daily_activities_normalized', 'social_use_normalized', 'depressed_normalized', 'sleep_issues_normalized']]
df_y23_normalized.columns = ['year', 'age', 'gender', 'occupation', 'stop_daily_activities', 'social_use', 'depressed', 'sleep_issues']


# Añadimos la fuente original al dataset como una columna, para poder tener un mejor tracking
df_k_normalized['source'] = 'Kaggle'
df_y21_normalized['source'] = 'YRBS21'
df_y23_normalized['source'] = 'YRBS23'
# Out:
# C:\Users\Multivac Desktop\AppData\Local\Temp\ipykernel_21184\3854097803.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_k_normalized['source'] = 'Kaggle'
# C:\Users\Multivac Desktop\AppData\Local\Temp\ipykernel_21184\3854097803.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_y21_normalized['source'] = 'YRBS21'
# C:\Users\Multivac Desktop\AppData\Local\Temp\ipykernel_21184\3854097803.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_y23_normalized['source'] = 'YRBS23'

# %%
print(df_k_normalized.head())
print(df_y21_normalized.head())
print(df_y23_normalized.head())
# Out:
#    year  age  gender          occupation stop_daily_activities  \
# 0  2022   21    Male  University Student                   Yes
# 1  2022   21  Female  University Student                   Yes
# 2  2022   21  Female  University Student                    No
# 3  2022   21  Female  University Student                   Yes
# 4  2022   21  Female  University Student                   Yes
#
#               social_use         depressed sleep_issues  source
# 0  Between 2 and 3 hours            Always          Yes  Kaggle
# 1      More than 5 hours            Always          Yes  Kaggle
# 2  Between 3 and 4 hours  Most of the time          Yes  Kaggle
# 3      More than 5 hours  Most of the time           No  Kaggle
# 4  Between 2 and 3 hours  Most of the time           No  Kaggle
#    year   age  gender      occupation stop_daily_activities  \
# 0  2021  16.0  Female  School Student                   Yes
# 1  2021  15.0    Male             NaN                   Yes
# 2  2021  15.0    Male  School Student                   Yes
# 3  2021  15.0    Male  School Student                    No
# 4  2021  14.0    Male  School Student                   Yes
#
#               social_use         depressed sleep_issues  source
# 0      More than 5 hours            Always          Yes  YRBS21
# 1      More than 5 hours  Most of the time           No  YRBS21
# 2      More than 5 hours  Most of the time           No  YRBS21
# 3  Between 3 and 4 hours            Rarely           No  YRBS21
# 4      More than 5 hours         Sometimes           No  YRBS21
#    year   age  gender      occupation stop_daily_activities  \
# 0  2023  14.0  Female  School Student                   Yes
# 1  2023  15.0    Male  School Student                    No
# 2  2023  16.0    Male  School Student                   Yes
# 3  2023  17.0  Female  School Student                   Yes
# 4  2023  14.0    Male  School Student                   Yes
#
#               social_use  depressed sleep_issues  source
# 0  Between 2 and 3 hours      Never           No  YRBS23
# 1      Less than an Hour  Sometimes           No  YRBS23
# 2      More than 5 hours     Rarely          Yes  YRBS23
# 3      More than 5 hours  Sometimes           No  YRBS23
# 4  Between 2 and 3 hours  Sometimes           No  YRBS23

# %%
# Concatenar datasets
df_combined = pd.concat([df_k_normalized, df_y21_normalized, df_y23_normalized], ignore_index=True)

df_combined.head()
# Out:
#    year   age  gender          occupation stop_daily_activities  \
# 0  2022  21.0    Male  University Student                   Yes
# 1  2022  21.0  Female  University Student                   Yes
# 2  2022  21.0  Female  University Student                    No
# 3  2022  21.0  Female  University Student                   Yes
# 4  2022  21.0  Female  University Student                   Yes
#
#               social_use         depressed sleep_issues  source
# 0  Between 2 and 3 hours            Always          Yes  Kaggle
# 1      More than 5 hours            Always          Yes  Kaggle
# 2  Between 3 and 4 hours  Most of the time          Yes  Kaggle
# 3      More than 5 hours  Most of the time           No  Kaggle
# 4  Between 2 and 3 hours  Most of the time           No  Kaggle

# %% [markdown]
# ## Análisis dataset combinado

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df_combined.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37816 entries, 0 to 37815
# Data columns (total 9 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   year                   37816 non-null  int64
#  1   age                    37620 non-null  float64
#  2   gender                 37394 non-null  object
#  3   occupation             37487 non-null  object
#  4   stop_daily_activities  37305 non-null  object
#  5   social_use             32180 non-null  object
#  6   depressed              28981 non-null  object
#  7   sleep_issues           31537 non-null  object
#  8   source                 37816 non-null  object
# dtypes: float64(1), int64(1), object(7)
# memory usage: 2.6+ MB

# %%
# Análisis de nulos
df_combined.isna().sum().sort_values(ascending = False)
# Out:
# depressed                8835
# sleep_issues             6279
# social_use               5636
# stop_daily_activities     511
# gender                    422
# occupation                329
# age                       196
# year                        0
# source                      0
# dtype: int64

# %% [markdown]
# Decidimos eliminar las filas con nulos, ya que puede deberse a nulos en las encuestas o a un mapeo insuficiente de las variables

# %%
df_combined_cleaned = df_combined.dropna()
df_combined_cleaned
# Out:
#        year   age  gender          occupation stop_daily_activities  \
# 0      2022  21.0    Male  University Student                   Yes
# 1      2022  21.0  Female  University Student                   Yes
# 2      2022  21.0  Female  University Student                    No
# 3      2022  21.0  Female  University Student                   Yes
# 4      2022  21.0  Female  University Student                   Yes
# ...     ...   ...     ...                 ...                   ...
# 35298  2023  15.0  Female      School Student                    No
# 35299  2023  18.0  Female      School Student                   Yes
# 35300  2023  18.0  Female      School Student                   Yes
# 35301  2023  17.0  Female      School Student                    No
# 35302  2023  17.0  Female      School Student                   Yes
#
#                   social_use         depressed sleep_issues  source
# 0      Between 2 and 3 hours            Always          Yes  Kaggle
# 1          More than 5 hours            Always          Yes  Kaggle
# 2      Between 3 and 4 hours  Most of the time          Yes  Kaggle
# 3          More than 5 hours  Most of the time           No  Kaggle
# 4      Between 2 and 3 hours  Most of the time           No  Kaggle
# ...                      ...               ...          ...     ...
# 35298  Between 3 and 4 hours  Most of the time          Yes  YRBS23
# 35299  Between 2 and 3 hours  Most of the time           No  YRBS23
# 35300      More than 5 hours            Always          Yes  YRBS23
# 35301      Less than an Hour            Rarely          Yes  YRBS23
# 35302  Between 2 and 3 hours         Sometimes           No  YRBS23
#
# [20884 rows x 9 columns]

# %%
# Cambiamos el tipo de age
df_combined_cleaned['age'] = df_combined_cleaned['age'].astype('int32')
# Out:
# C:\Users\Multivac Desktop\AppData\Local\Temp\ipykernel_21184\2228478740.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_combined_cleaned['age'] = df_combined_cleaned['age'].astype('int32')

# %% [markdown]
# ### Análisis exploratorio

# %%
# EDA variables categóricas
def graficos_eda_categoricos(cat):

    #Calculamos el número de filas que necesitamos
    from math import ceil
    filas = ceil(cat.shape[1] / 2)

    #Definimos el gráfico
    f, ax = plt.subplots(nrows = filas, ncols = 2, figsize = (16, filas * 6))

    #Aplanamos para iterar por el gráfico como si fuera de 1 dimensión en lugar de 2
    ax = ax.flat

    #Creamos el bucle que va añadiendo gráficos
    for cada, variable in enumerate(cat):
        cat[variable].value_counts().plot.barh(ax = ax[cada])
        ax[cada].set_title(variable, fontsize = 12, fontweight = "bold")
        ax[cada].tick_params(labelsize = 12)


graficos_eda_categoricos(df_combined_cleaned.select_dtypes('O'))

# %% [markdown]
# Dado que para la variable de género no disponemos de suficientes casos para los géneros no-binarios (únicamente 7), se deciden eliminar del dataset final

# %%
print(df_combined_cleaned[~df_combined_cleaned['gender'].isin(['Male', 'Female'])].shape[0])

df_combined_cleaned = df_combined_cleaned[df_combined_cleaned['gender'].isin(['Male', 'Female'])]
# Out:
# 7

# %%
# EDA variables numéricas
def estadisticos_cont(num):
    #Calculamos describe
    estadisticos = num.describe().T
    #Añadimos la mediana
    estadisticos['median'] = num.median()
    #Reordenamos para que la mediana esté al lado de la media
    estadisticos = estadisticos.iloc[:,[0,1,8,2,3,4,5,6,7]]
    #Lo devolvemos
    return(estadisticos)

estadisticos_cont(df_combined_cleaned.select_dtypes('number'))
# Out:
#         count         mean  median       std     min     25%     50%     75%  \
# year  20877.0  2022.078603  2023.0  0.985476  2021.0  2021.0  2023.0  2023.0
# age   20877.0    16.143986    16.0  2.436108    12.0    15.0    16.0    17.0
#
#          max
# year  2023.0
# age     91.0

# %% [markdown]
# No vemos nada raro en la variable de edad, el rango es plausible con un mínimo de 12 años y un máximo de 91; además de tener una media de 16 años.
# Dado que los cuestionarios de Youth Risk Behaviour representan la mayoría del dataset, es comprensible.

# %% [markdown]
# ### Exportar dataset de resultados
#
# Exportamos el dataset en la carpeta de `resultados`:

# %%
df_combined_cleaned.to_csv('resultados/dataset_combined.csv', index=False)
df_combined_cleaned.to_excel('resultados/dataset_combined.xlsx', index=False)

# %% [markdown]
# ### Generación de Insights
#
# ¿Hay alguna correlación entre un uso excesivo de las redes sociales y factores psicológicos?
