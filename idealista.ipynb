# %%
import pandas as pd
from urllib.request import urlopen
from bs4 import BeautifulSoup
from pathlib import Path
from selenium import webdriver
import locale
locale.setlocale(locale.LC_TIME, 'es_ES.UTF-8')
import plotly.express as px
import plotly.graph_objects as go

from aux_functions import get_html, extract_values, plot_data
# Out:
# /Users/francip/Desktop/Master/PRVD/PRVD-1/env/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(

# %% [markdown]
# ## Análisis del precio de la vivienda en Alicante (centro)

# %%
soup = get_html('htmls/alicante/historico_alicante_venta.html')
df_historico_precios_venta_alicante = extract_values(soup, divide=True)
plot_data(df_historico_precios_venta_alicante, title="Evolución del precio por m2 de la vivienda en Alicante (centro)")

# %%
soup = get_html('htmls/alicante/historico_alicante_alquiler.html')
df_historico_precios_alquiler_alicante = extract_values(soup)
plot_data(df_historico_precios_alquiler_alicante, title="Evolución del precio por m2 del aquiler en Alicante (centro)")

# %% [markdown]
# ## Análisis del precio de la vivienda en Barcelona (Gràcia)

# %%
soup = get_html('htmls/barcelona/historico_barcelona_venta.html')
df_historico_precios_venta_barcelona = extract_values(soup, divide=True)
plot_data(df_historico_precios_venta_barcelona, title="Evolución del precio por m2 de la vivienda en Barcelona (Gràcia)")

# %%
soup = get_html('htmls/barcelona/historico_barcelona_alquiler.html')
df_historico_precios_alquiler_barcelona = extract_values(soup)
plot_data(df_historico_precios_alquiler_barcelona, title="Evolución del precio por m2 del aquiler en Barcelona (Gràcia)")

# %% [markdown]
# ## Análisis del precio de la vivienda en Madrid (Chamartín)

# %%
soup = get_html('htmls/madrid/historico_madrid_ventas.html')
df_historico_precios_venta_madrid = extract_values(soup, divide=True)
plot_data(df_historico_precios_venta_madrid, title="Evolución del precio por m2 de la vivienda en Madrid (Chamartín)")

# %%
soup = get_html('htmls/madrid/historico_madrid_alquiler.html')
df_historico_precios_alquiler_madrid = extract_values(soup)
plot_data(df_historico_precios_alquiler_madrid, title="Evolución del precio por m2 del aquiler en Madrid (Charmartín)")
